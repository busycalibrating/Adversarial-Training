# %% [markdown]
# # Plot Adversarial Dataset

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
from adv_train.dataset import AdversarialDataset
from adv_train.model import load_mnist_dataset

# %%
dataset = load_mnist_dataset()
dataset = AdversarialDataset(dataset, n_adv=1)
# Out:
# /private/home/hberard/.local/lib/python3.8/site-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
fig = dataset.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
fig = dataset.plot_noise()
# Out:
# <img src="data:image/png;base64,..." width="640">
